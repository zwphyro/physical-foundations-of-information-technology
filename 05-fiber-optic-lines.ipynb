# %% [markdown]
# # Оптоволоконные линии

# %% [markdown]
# ## Оптический диапазон электромагнитных волн

# %% [markdown]
# Радио-излучение (ниже 300 ГГц)
# Терагерцовое излучение (300 ГГц - 3 ТГц)
# Инфракрасное излучение (150 ГГц - 405 ТГц)
# **Оптическое излучение (207 ТГц - 405 ТГц)**
# Ультрафиолетовое излучение
# Рентгеновское излучение
# $\gamma$-излучение

# %% [markdown]
# ## Технические характеристики оптических волокон

# %% [markdown]
# ![](./images/05-01.png)
#
# Приемущество оптических волокон - работа в высоком частотном диапазоне с низкими затуханиями электромагнитных волн.
#
# ![](./images/05-02.png)
#
# Одномодовый кабель способен работать при более высоких частотах, многомодовый кабель имеет большую пропускную способность.
#
# ![](./images/05-03.png)
#
# Данные в волноводе передаются с помощью радиоимпульсов.

# %% [markdown]
# ## Показатель преломления. Распространение света в неоднородной среде.

# %% [markdown]
# $
# n = \frac c v
# $
#
# ![](./images/05-04.png)
#
#
# $
# n_1 sin(\theta_1) = n_2 sin(\theta_2)
# $
#
# ![](./images/05-05.png)
#
# Использование волноводов с неоднородным показателем преломления в сердечнике позволяет уменьшить потери энергии при внутреннем отражении, а также сам луч стремится попасть в центр поперечного сечения волновода (в среду с большим показателем преломления).
